# %%
x=1
price=0
while x!=0:
  x= input('''
  Welcome to the Antheras Cafe (Menu) :
  1. Hot Coffee '\u2615'
  2. Cold Coffee '\u26FE'
  3. Snacks '\U0001F60B'
  4. Desert '\U0001F35B'
  Please select a category by entering its number,name or type 'exit' to finish: ''')
  x = x.casefold()
  match x :
    case '1'|'hot coffee':
      x1=input('''Please select an item from the 'Hot Coffe' '\u2615' category by entering its name or number or type 'exit' to finish :
          1.Cappucine ($2.3/iece) '\u2615'
          2.Cafe Late ($2.4/piece) '\U0001D86C'
          3.Velvet Coffee ($2.5/piece) '\U0001D872'
          4.Flat White ($2.41/piece) '\u222A'
          5.Cinamon Coffee ($2.43/piece) '\U0001D86D'
          Enter the name or number of the item you want to order: ''')
      x1 = x1.casefold()
      match(x1):
        case '1'|'cappucine':
          product='Cappucine' '\u2615'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 2.3*quantity
        case '2'|'cafe lite':
          product='Cafe Late' '\U0001D86C'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 2.4*quantity
        case '3'|'velvet coffee':
          product='Velvet Coffee' '\U0001D872'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 2.5*quantity
        case '4'|'flat white':
          product='Flat White' '\u222A'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 2.41*quantity
        case '5'|'cinamon cofeee':
          product='Cinamon Coffee' '\U0001D86D'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 2.43*quantity
        case 'exit':
          break
        case _:
          print('Choose correct item')
          continue
      print(f'{quantity}, {product} is added to your menu')
    case '2'|'cold Coffee':
      x2=input('''Please select an item from the 'Cold Coffe' '\u26FE' category by entering its name or number or type 'exit' to finish :
          1.Vegan Shake ($6.10/iece) '\U0001F964'
          2.Cold Coffee ($6.21/piece) '\u26FE'
          3.Iced Tea ($6.23/piece) '\U0001F367'
          4.Chilled Latte ($6.25/piece) '\U0001F9CA'
          5.Belgian ($6.12/piece) '\U0001F378'
          Enter the name or number of the item you want to order: ''')
      x2 = x2.casefold()
      match(x2):
        case '1'|'vegan shake':
          product='Vegan Shake' '\U0001F964'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 6.10*quantity
        case '2'|'cold coffee':
          product='Cold Coffee' '\u26FE'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 6.21*quantity
        case '3'|'iced tea':
          product='Iced Tea' '\U0001F367'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 6.23*quantity
        case '4'|'chilled latte':
          product='Chilled Latte' '\U0001F9CA'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 6.25*quantity
        case '5'|'belgian':
          product='Belgian' '\U0001F378'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 6.12*quantity
        case 'exit':
          break
        case _:
          print('Choose correct item')
          continue
      print(f'{quantity}, {product} is added to your menu')
    case '3'|'snacks':
      x3=input('''Please select an item from the 'Snacks' '\U0001F60B' category by entering its name or number or type 'exit' to finish:
          1.Sandwich ($8/piece) '\U0001F96A'
          2.Cottage Cheese Fry ($12.9/piece) '\U0001F9C0'
          3.Garlic Bread ($2/piece) '\U0001F35E'
          4.Bread Sticks ($7/piece) '\U0001F956'
          5.Veg Burger ($6.5/piece) '\U0001F354'
          Enter the name or number of the item you want to order: ''')
      x3 = x3.casefold()
      match(x3):
        case '1'|'sandwich':
          product='Sandwich' '\U0001F96A'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 8*quantity
        case '2'|'cottage cheese fry':
          product='Cottage Cheese Fry' '\U0001F9C0'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 12.9*quantity
        case '3'|'garlic bread':
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 2*quantity
          product='Garlic Bread' '\U0001F35E'
          quantity = int(input(f'Enter the quantity of {product}: '))
        case '4'|'bread sticks':
          product='Bread Sticks' '\U0001F956'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 7*quantity
        case '5'|'veg burger':
          product='Veg Burger' '\U0001F354'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 6.5*quantity
        case 'exit':
          break
        case _:
          print('Choose correct item')
          continue
      print(f'{quantity}, {product} is added to your menu')
    case '4'|'desert':
      x4=input(''''Please selct a category from the 'Desert' '\U0001F35B' by entering its name, number or type 'exit' to finish :
          1.Cheesecake($17/piece) '\U0001F370'
          2.Choco Fantasy ($26/piece) '\U0001F36B'
          3.Brownie ($12/piece) '\U0001F7E4'
          4.Choco Fudge ($18/piece) '\U0001F36A'
          5.Vanilla Scoop ($16/piece) '\U0001F96B'
          Enter the name or number of the item you want to order: ''')
      x4 = x4.casefold()
      match(x4):
        case '1'|'cheese cake':
          product='Cheesecake' '\U0001F370'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 17*quantity
        case '2'|'choco fantasy':
          product='Choco Fantasy' '\U0001F36B'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 26*quantity
        case '3'|'brownie':
          product='Brownie' '\U0001F7E4'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 12*quantity
        case '4'|'choco fudge':
          product='Choco Fudge' '\U0001F36A'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 18*quantity
        case '5'|'vanilla scoop':
          product='Vanilla Scoop' '\U0001F96B'
          quantity = int(input(f'Enter the quantity of {product}: '))
          price+= 16*quantity
        case 'exit':
          break
        case _:
          print('Choose correct item')
          continue
      print(f'{quantity}, {product} is added to your menu')
    case '0'|'exit':
      break
    case _ :
      print('Chhose valid option')
print(f'Total amount : {price}$')
# Out:
#   Welcome to the Antheras Cafe (Menu) :
#   1. Hot Coffee '☕'
#   2. Cold Coffee '⛾'
#   3. Snacks '😋'
#   4. Desert '🍛'
#   Please select a category by entering its number,name or type 'exit' to finish: 1
# Please select an item from the 'Hot Coffe' '☕' category by entering its name or number or type 'exit' to finish :
#           1.Cappucine ($2.3/iece) '☕'
#           2.Cafe Late ($2.4/piece) '𝡬'
#           3.Velvet Coffee ($2.5/piece) '𝡲'
#           4.Flat White ($2.41/piece) '∪'
#           5.Cinamon Coffee ($2.43/piece) '𝡭'
#           Enter the name or number of the item you want to order: 3
# Enter the quantity of Velvet Coffee𝡲: 5
# 5, Velvet Coffee𝡲 is added to your menu
#
#   Welcome to the Antheras Cafe (Menu) :
#   1. Hot Coffee '☕'
#   2. Cold Coffee '⛾'
#   3. Snacks '😋'
#   4. Desert '🍛'
#   Please select a category by entering its number,name or type 'exit' to finish: exit
# Total amount : 12.5$
